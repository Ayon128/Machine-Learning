# %%
import pandas as pd

# %%
df=pd.read_csv('E:\\Machine_Learning\student_1.csv')
df
# Out:
#    Student ID Date  Class  Study hrs  Sleeping h  Social media    Mobile  \
# 0        1001  Yes     10          2           5             1         1
# 1        1002  Yes     10          6           6             3         0
# 2        1003  Yes     10          3           7             4         2
# 3        1004   No     11          4           8             5         3
# 4        1005  Yes     11          5           9             6         4
# 5        1006   No     11          6          10             7         6
# 6        1007  Yes     12          9          11             8         5
# 7        1008   No     12         10          12             9         7
# 8        1009  Yes     12         12           8            10         8
# 9        1010  Yes     12          1          12            11         9
#
#    Percentage
# 0          50
# 1          80
# 2          70
# 3          85
# 4          70
# 5          60
# 6          90
# 7          95
# 8          90
# ...

# %%
df=pd.read_csv('E:\\Machine_Learning\student_1.csv')
df
# Out:
#    Student ID Date  Class  Study hrs  Sleeping h  Social media    Mobile  \
# 0        1001  Yes   10.0          2           5             1         1
# 1        1002  Yes   10.0          6           6             3         0
# 2        1003  Yes   10.0          3           7             4         2
# 3        1004   No   11.0          4           8             5         3
# 4        1005  Yes    NaN          5           9             6         4
# 5        1006   No    NaN          6          10             7         6
# 6        1007  Yes    NaN          9          11             8         5
# 7        1008   No   12.0         10          12             9         7
# 8        1009  Yes   12.0         12           8            10         8
# 9        1010  Yes    NaN          1          12            11         9
#
#    Percentage
# 0        50.0
# 1        80.0
# 2        90.0
# 3        95.0
# 4        90.0
# 5        80.0
# 6         NaN
# 7         NaN
# 8         NaN
# ...

# %%
df=pd.read_csv('E:\\Machine_Learning\student_1.csv')
df
# Out:
#    Student ID Date  Class  Study hrs  Sleeping h  Social media    Mobile  \
# 0        1001  Yes   10.0          2           5             1         1
# 1        1002  Yes   10.0          6           6             3         0
# 2        1003  Yes    NaN          3           7             4         2
# 3        1004   No    NaN          4           8             5         3
# 4        1005  Yes    NaN          5           9             6         4
# 5        1006   No    NaN          6          10             7         6
# 6        1007  Yes    NaN          9          11             8         5
# 7        1008   No   12.0         10          12             9         7
# 8        1009  Yes   12.0         12           8            10         8
# 9        1010  Yes    NaN          1          12            11         9
#
#       Percentage
# 0             50
# 1             80
# 2             90
# 3             95
# 4             90
# 5             80
# 6            NaN
# ...

# %%
df=pd.read_csv('E:\\Machine_Learning\student_1.csv',na_values=['Not available','No values'])#na _values used to consider the unnecessary data as NAN
df
# Out:
#    Student ID Date  Class  Study hrs  Sleeping h  Social media    Mobile  \
# 0        1001  Yes   10.0          2           5             1         1
# 1        1002  Yes   10.0          6           6             3         0
# 2        1003  Yes    NaN          3           7             4         2
# 3        1004   No    NaN          4           8             5         3
# 4        1005  Yes    NaN          5           9             6         4
# 5        1006   No    NaN          6          10             7         6
# 6        1007  Yes    NaN          9          11             8         5
# 7        1008   No    NaN         10          12             9         7
# 8        1009  Yes   12.0         12           8            10         8
# 9        1010  Yes    NaN          1          12            11         9
#
#    Percentage
# 0        50.0
# 1        80.0
# 2        90.0
# 3        95.0
# 4        90.0
# 5        80.0
# 6         NaN
# 7         NaN
# 8         NaN
# ...

# %%
df=pd.read_csv('E:\\Machine_Learning\student_1.csv',na_values ={'Class' : 'No values','Percentage' : 'Not available'})#using dictionary to specific coloumn handling NAN values
df
# Out:
#    Student ID Date  Class  Study hrs  Sleeping h  Social media    Mobile  \
# 0        1001  Yes   10.0          2           5             1         1
# 1        1002  Yes   10.0          6           6             3         0
# 2        1003  Yes    NaN          3           7             4         2
# 3        1004   No    NaN          4           8             5         3
# 4        1005  Yes    NaN          5           9             6         4
# 5        1006   No    NaN          6          10             7         6
# 6        1007  Yes    NaN          9          11             8         5
# 7        1008   No    NaN         10          12             9         7
# 8        1009  Yes   12.0         12           8            10         8
# 9        1010  Yes    NaN          1          12            11         9
#
#    Percentage
# 0        50.0
# 1        80.0
# 2        90.0
# 3        95.0
# 4        90.0
# 5        80.0
# 6         NaN
# 7         NaN
# 8         NaN
# ...

# %%
df=pd.read_csv('E:\\Machine_Learning\student_1.csv')
df
# Out:
#    Student ID Date      Class  Study hrs  Sleeping h  Social media    Mobile  \
# 0        1001  Yes         10          2           5             1         1
# 1        1002  Yes         10          6           6             3         0
# 2        1003  Yes        NaN          3           7             4         2
# 3        1004   No        NaN          4           8             5         3
# 4        1005  Yes        NaN          5           9             6         4
# 5        1006   No        NaN          6          10             7         6
# 6        1007  Yes        NaN          9          11             8         5
# 7        1008   No  No values         10          12             9         7
# 8        1009  Yes         12         12           8            10         8
# 9        1010  Yes        NaN          1          12            11         9
#
#       Percentage
# 0             50
# 1             80
# 2             90
# 3             95
# 4             90
# ...

# %%
df=pd.read_csv('E:\\Machine_Learning\student_1.csv',keep_default_na=False)
df
# Out:
#    Student ID Date      Class  Study hrs  Sleeping h  Social media    Mobile  \
# 0        1001  Yes         10          2           5             1         1
# 1        1002  Yes         10          6           6             3         0
# 2        1003  Yes       #N/A          3           7             4         2
# 3        1004   No       #N/A          4           8             5         3
# 4        1005  Yes       #N/A          5           9             6         4
# 5        1006   No       #N/A          6          10             7         6
# 6        1007  Yes       #N/A          9          11             8         5
# 7        1008   No  No values         10          12             9         7
# 8        1009  Yes         12         12           8            10         8
# 9        1010  Yes                     1          12            11         9
#
#       Percentage
# 0             50
# 1             80
# 2             90
# 3             95
# 4             90
# ...

# %%
df=pd.read_csv('E:\\Machine_Learning\student_1.csv',keep_default_na=True)
df
# Out:
#    Student ID Date      Class  Study hrs  Sleeping h  Social media    Mobile  \
# 0        1001  Yes         10          2           5             1         1
# 1        1002  Yes         10          6           6             3         0
# 2        1003  Yes        NaN          3           7             4         2
# 3        1004   No        NaN          4           8             5         3
# 4        1005  Yes        NaN          5           9             6         4
# 5        1006   No        NaN          6          10             7         6
# 6        1007  Yes        NaN          9          11             8         5
# 7        1008   No  No values         10          12             9         7
# 8        1009  Yes         12         12           8            10         8
# 9        1010  Yes        NaN          1          12            11         9
#
#       Percentage
# 0             50
# 1             80
# 2             90
# 3             95
# 4             90
# ...

# %%
df=pd.read_csv('E:\\Machine_Learning\student_1.csv')
df
# Out:
#    Student ID Date  Class  Study hrs  Sleeping h  Social media    Mobile  \
# 0        1001  Yes     10          2           5             1         1
# 1        1002  Yes     10          6           6             3         0
# 2        1003  Yes     10          3           7             4         2
# 3        1004   No     11          4           8             5         3
# 4        1005  Yes     11          5           9             6         4
# 5        1006   No     11          6          10             7         6
# 6        1007  Yes     12          9          11             8         5
# 7        1008   No     12         10          12             9         7
# 8        1009  Yes     12         12           8            10         8
# 9        1010  Yes     12          1          12            11         9
#
#    Percentage
# 0          50
# 1          80
# 2          70
# 3          85
# 4          70
# 5          60
# 6          90
# 7          95
# 8          90
# ...

# %%
df=pd.read_csv('E:\\Machine_Learning\student_1.csv',na_filter=False)#na_filter used when there is no missing value or unnecessary data in csv file
df
# Out:
#    Student ID Date  Class  Study hrs  Sleeping h  Social media    Mobile  \
# 0        1001  Yes     10          2           5             1         1
# 1        1002  Yes     10          6           6             3         0
# 2        1003  Yes     10          3           7             4         2
# 3        1004   No     11          4           8             5         3
# 4        1005  Yes     11          5           9             6         4
# 5        1006   No     11          6          10             7         6
# 6        1007  Yes     12          9          11             8         5
# 7        1008   No     12         10          12             9         7
# 8        1009  Yes     12         12           8            10         8
# 9        1010  Yes     12          1          12            11         9
#
#    Percentage
# 0          50
# 1          80
# 2          70
# 3          85
# 4          70
# 5          60
# 6          90
# 7          95
# 8          90
# ...

# %%
df.isnull()#isnull used for checking whether is there any NAN present
# Out:
#    Student ID   Date  Class  Study hrs  Sleeping h  Social media    Mobile  \
# 0       False  False  False      False       False         False     False
# 1       False  False  False      False       False         False     False
# 2       False  False  False      False       False         False     False
# 3       False  False  False      False       False         False     False
# 4       False  False  False      False       False         False     False
# 5       False  False  False      False       False         False     False
# 6       False  False  False      False       False         False     False
# 7       False  False  False      False       False         False     False
# 8       False  False  False      False       False         False     False
# 9       False  False  False      False       False         False     False
#
#    Percentage
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# ...

# %%
df=pd.read_csv('E:\\Machine_Learning\student_1.csv')
df
# Out:
#    Student ID Date  Class  Study hrs  Sleeping h  Social media    Mobile  \
# 0        1001  Yes   10.0          2           5           1.0         1
# 1        1002  Yes   10.0          6           6           3.0         0
# 2        1003  Yes   10.0          3           7           NaN         2
# 3        1004   No    NaN          4           8           NaN         3
# 4        1005  Yes    NaN          5           9           NaN         4
# 5        1006   No    NaN          6          10           NaN         6
# 6        1007  Yes    NaN          9          11           8.0         5
# 7        1008   No   12.0         10          12           9.0         7
# 8        1009  Yes   12.0         12           8          10.0         8
# 9        1010  Yes   12.0          1          12          11.0         9
#
#    Percentage
# 0        50.0
# 1        80.0
# 2        70.0
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7        95.0
# 8        90.0
# ...

# %%
df.isnull().sum()#count the NAN in every  coloumn
# Out:
# Student ID      0
# Date            0
# Class           4
# Study hrs       0
# Sleeping h      0
# Social media    4
#   Mobile        0
# Percentage      4
# dtype: int64

# %%
df.isnull().sum().sum()#return the total NAN values in csv file
# Out:
# 12

# %%
df.notnull()
# Out:
#    Student ID  Date  Class  Study hrs  Sleeping h  Social media    Mobile  \
# 0        True  True   True       True        True          True      True
# 1        True  True   True       True        True          True      True
# 2        True  True   True       True        True         False      True
# 3        True  True  False       True        True         False      True
# 4        True  True  False       True        True         False      True
# 5        True  True  False       True        True         False      True
# 6        True  True  False       True        True          True      True
# 7        True  True   True       True        True          True      True
# 8        True  True   True       True        True          True      True
# 9        True  True   True       True        True          True      True
#
#    Percentage
# 0        True
# 1        True
# 2        True
# 3       False
# 4       False
# 5       False
# 6       False
# 7        True
# ...

# %%
df.notnull().sum()
# Out:
# Student ID      10
# Date            10
# Class            6
# Study hrs       10
# Sleeping h      10
# Social media     6
#   Mobile        10
# Percentage       6
# dtype: int64

# %%
df.notnull().sum().sum()
# Out:
# 68

# %%
import numpy as np
sr=pd.Series([1,2,3,4,5,np.NAN,np.nan])
sr
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    5.0
# 5    NaN
# 6    NaN
# dtype: float64

# %%
sr.isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6     True
# dtype: bool

# %%
sr.isnull().sum()
# Out:
# 2

# %%
df=pd.read_csv('E:\\Machine_Learning\student_1.csv')
df
# Out:
#    Student ID Date  Class  Study hrs  Sleeping h  Social media    Mobile  \
# 0        1001  Yes   10.0          2           5           1.0         1
# 1        1002  Yes   10.0          6           6           3.0         0
# 2        1003  Yes   10.0          3           7           NaN         2
# 3        1004   No    NaN          4           8           NaN         3
# 4        1005  Yes    NaN          5           9           NaN         4
# 5        1006   No    NaN          6          10           NaN         6
# 6        1007  Yes    NaN          9          11           8.0         5
# 7        1008   No   12.0         10          12           9.0         7
# 8        1009  Yes   12.0         12           8          10.0         8
# 9        1010  Yes   12.0          1          12          11.0         9
#
#    Percentage
# 0        50.0
# 1        80.0
# 2        70.0
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7        95.0
# 8        90.0
# ...

# %%
df.dropna() #dropna is used to drop/remove values NAN
# Out:
#    Student ID Date  Class  Study hrs  Sleeping h  Social media    Mobile  \
# 0        1001  Yes   10.0          2           5           1.0         1
# 1        1002  Yes   10.0          6           6           3.0         0
# 7        1008   No   12.0         10          12           9.0         7
# 8        1009  Yes   12.0         12           8          10.0         8
# 9        1010  Yes   12.0          1          12          11.0         9
#
#    Percentage
# 0        50.0
# 1        80.0
# 7        95.0
# 8        90.0
# 9        80.0

# %%
 df.dropna(axis=1)#remove the coloumns containing NAN
# Out:
#    Student ID Date  Study hrs  Sleeping h    Mobile
# 0        1001  Yes          2           5         1
# 1        1002  Yes          6           6         0
# 2        1003  Yes          3           7         2
# 3        1004   No          4           8         3
# 4        1005  Yes          5           9         4
# 5        1006   No          6          10         6
# 6        1007  Yes          9          11         5
# 7        1008   No         10          12         7
# 8        1009  Yes         12           8         8
# 9        1010  Yes          1          12         9

# %%
 df.dropna(axis=0)#remove the rows containing NAN

# %%
df.dropna(how ='any')#how ='any' it removes the row(by default axis=0 )/coloumn (axis=1) containing NAN
# Out:
#    Student ID Date  Class  Study hrs  Sleeping h  Social media    Mobile  \
# 0        1001  Yes   10.0          2           5           1.0         1
# 1        1002  Yes   10.0          6           6           3.0         0
# 7        1008   No   12.0         10          12           9.0         7
# 8        1009  Yes   12.0         12           8          10.0         8
# 9        1010  Yes   12.0          1          12          11.0         9
#
#    Percentage
# 0        50.0
# 1        80.0
# 7        95.0
# 8        90.0
# 9        80.0

# %%
df.dropna(axis =1 ,how ='any')
# Out:
#    Student ID Date  Study hrs  Sleeping h    Mobile
# 0        1001  Yes          2           5         1
# 1        1002  Yes          6           6         0
# 2        1003  Yes          3           7         2
# 3        1004   No          4           8         3
# 4        1005  Yes          5           9         4
# 5        1006   No          6          10         6
# 6        1007  Yes          9          11         5
# 7        1008   No         10          12         7
# 8        1009  Yes         12           8         8
# 9        1010  Yes          1          12         9

# %%
df.dropna(how = 'all')#it removes rows or coloumns if all values of rows or coloumns are NAN
# Out:
#    Student ID Date  Class  Study hrs  Sleeping h  Social media    Mobile  \
# 0        1001  Yes   10.0          2           5           1.0         1
# 1        1002  Yes   10.0          6           6           3.0         0
# 2        1003  Yes   10.0          3           7           NaN         2
# 3        1004   No    NaN          4           8           NaN         3
# 4        1005  Yes    NaN          5           9           NaN         4
# 5        1006   No    NaN          6          10           NaN         6
# 6        1007  Yes    NaN          9          11           8.0         5
# 7        1008   No   12.0         10          12           9.0         7
# 8        1009  Yes   12.0         12           8          10.0         8
# 9        1010  Yes   12.0          1          12          11.0         9
#
#    Percentage
# 0        50.0
# 1        80.0
# 2        70.0
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7        95.0
# 8        90.0
# ...

# %%
df=pd.read_csv('E:\\Machine_Learning\student_1.csv')
df
# Out:
#    Student ID Date  Class  Study hrs  Sleeping h  Social media    Mobile  \
# 0      1001.0  Yes   10.0        2.0         5.0           1.0       1.0
# 1      1002.0  Yes   10.0        6.0         6.0           3.0       0.0
# 2      1003.0  Yes   10.0        3.0         7.0           NaN       2.0
# 3      1004.0   No    NaN        4.0         8.0           NaN       3.0
# 4      1005.0  Yes    NaN        5.0         9.0           NaN       4.0
# 5      1006.0   No    NaN        6.0        10.0           NaN       6.0
# 6      1007.0  Yes    NaN        9.0        11.0           8.0       5.0
# 7      1008.0   No   12.0       10.0        12.0           9.0       7.0
# 8      1009.0  Yes   12.0       12.0         8.0          10.0       8.0
# 9         NaN  NaN    NaN        NaN         NaN           NaN       NaN
#
#    Percentage
# 0        50.0
# 1        80.0
# 2        70.0
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7        95.0
# 8        90.0
# ...

# %%
df.dropna(how ='all')#removes the 9th row
# Out:
#    Student ID Date  Class  Study hrs  Sleeping h  Social media    Mobile  \
# 0      1001.0  Yes   10.0        2.0         5.0           1.0       1.0
# 1      1002.0  Yes   10.0        6.0         6.0           3.0       0.0
# 2      1003.0  Yes   10.0        3.0         7.0           NaN       2.0
# 3      1004.0   No    NaN        4.0         8.0           NaN       3.0
# 4      1005.0  Yes    NaN        5.0         9.0           NaN       4.0
# 5      1006.0   No    NaN        6.0        10.0           NaN       6.0
# 6      1007.0  Yes    NaN        9.0        11.0           8.0       5.0
# 7      1008.0   No   12.0       10.0        12.0           9.0       7.0
# 8      1009.0  Yes   12.0       12.0         8.0          10.0       8.0
#
#    Percentage
# 0        50.0
# 1        80.0
# 2        70.0
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7        95.0
# 8        90.0

# %%
df.dropna(thresh=1) #thresh returns coloumns or rows(by default if no axis is initialize) if there is at least one  NotNull value
# Out:
#    Student ID Date  Class  Study hrs  Sleeping h  Social media    Mobile  \
# 0      1001.0  Yes   10.0        2.0         5.0           1.0       1.0
# 1      1002.0  Yes   10.0        6.0         6.0           3.0       0.0
# 2      1003.0  Yes   10.0        3.0         7.0           NaN       2.0
# 3      1004.0   No    NaN        4.0         8.0           NaN       3.0
# 4      1005.0  Yes    NaN        5.0         9.0           NaN       4.0
# 5      1006.0   No    NaN        6.0        10.0           NaN       6.0
# 6      1007.0  Yes    NaN        9.0        11.0           8.0       5.0
# 7      1008.0   No   12.0       10.0        12.0           9.0       7.0
# 8      1009.0  Yes   12.0       12.0         8.0          10.0       8.0
#
#    Percentage
# 0        50.0
# 1        80.0
# 2        70.0
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7        95.0
# 8        90.0

# %%
df.dropna(thresh =2)#thresh returns coloumns or rows(by default if no axis is initialize) if there are at least two  NotNull value
# Out:
#    Student ID Date  Class  Study hrs  Sleeping h  Social media    Mobile  \
# 0      1001.0  Yes   10.0        2.0         5.0           1.0       1.0
# 1      1002.0  Yes   10.0        6.0         6.0           3.0       0.0
# 2      1003.0  Yes   10.0        3.0         7.0           NaN       2.0
# 3      1004.0   No    NaN        4.0         8.0           NaN       3.0
# 4      1005.0  Yes    NaN        5.0         9.0           NaN       4.0
# 5      1006.0   No    NaN        6.0        10.0           NaN       6.0
# 6      1007.0  Yes    NaN        9.0        11.0           8.0       5.0
# 7      1008.0   No   12.0       10.0        12.0           9.0       7.0
# 8      1009.0  Yes   12.0       12.0         8.0          10.0       8.0
#
#    Percentage
# 0        50.0
# 1        80.0
# 2        70.0
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7        95.0
# 8        90.0

# %%
df=pd.read_csv('E:\\Machine_Learning\student_1.csv')
df
# Out:
#    Student ID Date  Class  Study hrs  Sleeping h  Social media    Mobile  \
# 0      1001.0  Yes   10.0        2.0         5.0           1.0       1.0
# 1      1002.0  Yes   10.0        6.0         6.0           3.0       0.0
# 2      1003.0  Yes   10.0        3.0         7.0           NaN       2.0
# 3      1004.0   No    NaN        4.0         8.0           NaN       3.0
# 4      1005.0  Yes    NaN        5.0         9.0           NaN       4.0
# 5      1006.0   No    NaN        6.0        10.0           NaN       6.0
# 6      1007.0  Yes    NaN        9.0        11.0           8.0       5.0
# 7      1008.0   No   12.0       10.0        12.0           9.0       7.0
# 8      1009.0  Yes   12.0       12.0         8.0          10.0       8.0
# 9         NaN  NaN    NaN        NaN         NaN           NaN       NaN
#
#    Percentage
# 0        50.0
# 1        80.0
# 2        70.0
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7        95.0
# 8        90.0
# ...

# %%
df.dropna(subset=['Student ID'])#subset works on coloumn Here (student id a last row te NaN ase tai ota remove hoise)
# Out:
#    Student ID Date  Class  Study hrs  Sleeping h  Social media    Mobile  \
# 0      1001.0  Yes   10.0        2.0         5.0           1.0       1.0
# 1      1002.0  Yes   10.0        6.0         6.0           3.0       0.0
# 2      1003.0  Yes   10.0        3.0         7.0           NaN       2.0
# 3      1004.0   No    NaN        4.0         8.0           NaN       3.0
# 4      1005.0  Yes    NaN        5.0         9.0           NaN       4.0
# 5      1006.0   No    NaN        6.0        10.0           NaN       6.0
# 6      1007.0  Yes    NaN        9.0        11.0           8.0       5.0
# 7      1008.0   No   12.0       10.0        12.0           9.0       7.0
# 8      1009.0  Yes   12.0       12.0         8.0          10.0       8.0
#
#    Percentage
# 0        50.0
# 1        80.0
# 2        70.0
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7        95.0
# 8        90.0

# %%
df.dropna(subset=['Social media'])#subset works on coloumn Here (Social media a jay  row te NaN ase tai oigulla remove hoise)
# Out:
#    Student ID Date  Class  Study hrs  Sleeping h  Social media    Mobile  \
# 0      1001.0  Yes   10.0        2.0         5.0           1.0       1.0
# 1      1002.0  Yes   10.0        6.0         6.0           3.0       0.0
# 6      1007.0  Yes    NaN        9.0        11.0           8.0       5.0
# 7      1008.0   No   12.0       10.0        12.0           9.0       7.0
# 8      1009.0  Yes   12.0       12.0         8.0          10.0       8.0
#
#    Percentage
# 0        50.0
# 1        80.0
# 6         NaN
# 7        95.0
# 8        90.0

# %%
df.dropna(subset=['Percentage'])#subset works on coloumn Here (Percentage a jay row te NaN ase tai oigulla remove hoise)
# Out:
#    Student ID Date  Class  Study hrs  Sleeping h  Social media    Mobile  \
# 0      1001.0  Yes   10.0        2.0         5.0           1.0       1.0
# 1      1002.0  Yes   10.0        6.0         6.0           3.0       0.0
# 2      1003.0  Yes   10.0        3.0         7.0           NaN       2.0
# 7      1008.0   No   12.0       10.0        12.0           9.0       7.0
# 8      1009.0  Yes   12.0       12.0         8.0          10.0       8.0
#
#    Percentage
# 0        50.0
# 1        80.0
# 2        70.0
# 7        95.0
# 8        90.0

# %%
df.dropna(inplace =True)#inplace removes rows containing NaN values but it dosen't create new DataFrame(mainly it update the main DataFrame)
df
# Out:
#    Student ID Date  Class  Study hrs  Sleeping h  Social media    Mobile  \
# 0      1001.0  Yes   10.0        2.0         5.0           1.0       1.0
# 1      1002.0  Yes   10.0        6.0         6.0           3.0       0.0
# 7      1008.0   No   12.0       10.0        12.0           9.0       7.0
# 8      1009.0  Yes   12.0       12.0         8.0          10.0       8.0
#
#    Percentage
# 0        50.0
# 1        80.0
# 7        95.0
# 8        90.0
