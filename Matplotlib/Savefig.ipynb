# %%
import matplotlib.pyplot as plt

# %%
plt.pie([10,20,35])
plt.savefig("Pie Chart")
plt.show()

# %%
plt.pie([10,20,35])
plt.savefig("Pie Chart",facecolor = 'g',)#facecolor is used to colour the background
plt.show()
